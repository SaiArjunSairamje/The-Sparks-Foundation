# %% [markdown]
# # <center><font color=red><ins>GRIP - The Spark Foundation</ins></font></center>

# %% [markdown]
# ![TheSparksFoundation.png](attachment:TheSparksFoundation.png)

# %% [markdown]
# ### <center>Internship on</center>

# %% [markdown]
# ## <center><font color=darkblue><ins>Data Science & Business Analytics</ins></font></center>

# %% [markdown]
# ### <center><font color=darkblue>Name</font>: Sai Arjun Sairamje</center>

# %% [markdown]
# ## <font color=darkblue><ins>Task (3)</ins>: Exploratory Data Analysis - Retail</font>

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# From the given ‘SampleSuperstore’ dataset, we will predict the following:
#
# (1) Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
# (2) As a business manager, try to find out the weak areas where you can work to make more profit
# (3) What all business problems you can derive by exploring the data?
#
# Dataset: https://bit.ly/3i4rbWl

# %% [markdown]
# ## Importing libraries

# %%
#importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the SampleSuperstore Dataset into the Jupyter notebook

# %%
#loading dataset

dataset = pd.read_csv("E:\(Intern) Sparks Foundation - GRIP\Task 3 - Exploratory Data Analysis - Retail\SampleSuperstore.csv")

# %% [markdown]
# ## Understanding the data from "SampleSuperstore.csv"

# %%
dataset.head()   #First 5 rows of the columns
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
dataset.tail()  #Last 5 rows of the columns
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
dataset.shape    #shape of the dataset (i.e. displays number of rows & columns)
# Out:
# (9994, 13)

# %%
dataset.describe()    #only the Integer objects of the dataset will appear
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
dataset.columns    #displays the column headers
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
dataset.nunique()    #It returns a scalar value which is the count of all the unique values in the Index
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
dataset['Region'].unique()    #to check unique values for any column
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
dataset['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %% [markdown]
# ## Cleaning the data

# %%
dataset.isnull().sum()    #detect missing values in the given dataset
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
dataset = dataset.drop(['Postal Code'],axis = 1)    #dropping postal code columns

# %% [markdown]
# ## Relationship analysis

# %%
# Correlation Matrix - which gives a wider perspective on what exactly are we dealing with here. 
# It is used to summarize data as an input into a more advanced analysis

correlation = dataset.corr()

# %%
sns.heatmap(correlation, annot = True, cmap ='rocket_r')

# %% [markdown]
# ### From above Heatmap:
#
# 1. Sales and Profit are Moderately Correlated
# 2. Discount and Profit are Negatively Correlated
# 3. Quantity and Profit are less Moderately Correlated

# %% [markdown]
# ## Pairplot for analyse each column

# %% [markdown]
# #### [1] Based on Category

# %%
sns.pairplot(dataset, hue='Category')

# %% [markdown]
# #### [2] Based on Region

# %%
sns.pairplot(dataset ,hue='Region')

# %% [markdown]
# #### [3] Based on Segment

# %%
sns.pairplot(dataset, hue='Segment')

# %%
dataset.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# ## Count Plots of each Column

# %%
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,7));

sns.countplot(dataset['Category'],ax=axs[0][0])
sns.countplot(dataset['Segment'],ax=axs[0][1])
sns.countplot(dataset['Ship Mode'],ax=axs[1][0])
sns.countplot(dataset['Region'],ax=axs[1][1])
axs[0][0].set_title('Category',fontsize=20)
axs[0][1].set_title('Segment',fontsize=20)
axs[1][0].set_title('Ship Mode',fontsize=20)
axs[1][1].set_title('Region',fontsize=20)


plt.tight_layout()

# %%
plt.figure(figsize=(20,8))
sns.countplot(dataset['Sub-Category'])
plt.title('Sub-Category',fontsize=20)
# Out:
# Text(0.5,1,'Sub-Category')

# %% [markdown]
# Maximum are from Binders, Paper, Furnishings, Phones, Storage, Art, Accessories, &
# Minimum from Copiers, Machines, Suppliers

# %%
plt.figure(figsize=(15,12))
sns.countplot(x='State', data=dataset, palette='rocket_r',order=dataset['State'].value_counts().index)
plt.xticks(rotation=90)
plt.title('State',fontsize=20)
plt.show()

# %% [markdown]
# Highest number of buyers are from "Calofornia" and "Newyork"

# %%
dataset.hist(figsize=(10,10),bins=50)
plt.show()

# %% [markdown]
# 1. Most customers tends to buy quantity of 2 and 3
# 2. Discount give maximum is 0 to 20 percent

# %%
plt.figure(figsize=(8,8))
dataset['Region'].value_counts().plot.pie(autopct = '%1.1f%%')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(20,8))
ax.scatter(dataset['Sales'],dataset['Profit'])
ax.set_xlabel('Sales')
ax.set_ylabel('Profit')
plt.show()

# %%
dataset.groupby('Segment')[['Profit','Sales']].sum().plot.bar(color=['green','yellow'],figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %% [markdown]
# Profi and sales are "maximum in consumer segment" and "minimum in Home Office segment"

# %%
plt.figure(figsize=(12,8))
plt.title('Segment wise Sales in each Region')
sns.barplot(x='Region',y='Sales',data=dataset,hue='Segment',order=dataset['Region'].value_counts().index,palette='rocket')
plt.xlabel('Region',fontsize=15)
plt.show()

# %% [markdown]
# segment wise sales are almost same in every region

# %%
dataset.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['darkblue','skyblue'],figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %% [markdown]
# profit and sales are "maximum in west region" and "minimum in south region"

# %%
ps = dataset.groupby('State')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(color=['pink','blue'],figsize=(15,8))
plt.title('Profit/loss & Sales across states')
plt.xlabel('States')
plt.ylabel('Profit/loss & Sales')
plt.show()

# %% [markdown]
# high profit is for california, new york
# loss is for texas, pennsylvania, Ohio

# %%
t_states = dataset['State'].value_counts().nlargest(10)
t_states
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
dataset.groupby('Category')[['Profit','Sales']].sum().plot.bar(color=['pink','red'],alpha=0.9,figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %% [markdown]
# #### As a business manager, try to find out the weak areas where you can work to make more profit?

# %% [markdown]
# 1. Technology and Office Supplies have high profit.
# 2. Furniture have less profit

# %%
ps = dataset.groupby('Sub-Category')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(color=['purple','yellow'],figsize=(15,8))
plt.title('Profit/loss & Sales across states')
plt.xlabel('Sub-Category')
plt.ylabel('Profit/loss & Sales')
plt.show()

# %% [markdown]
# 1. Phones sub-category have high sales.
# 2. chairs have high sales but less profit compared to phones
# 3. Tables and Bookmarks sub-categories facing huge loss

# %% [markdown]
# ### --------------------- This concludes the Exploratory Data Analysis Workshop ---------------------
